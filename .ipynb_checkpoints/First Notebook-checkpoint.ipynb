# %% [markdown]
# # <b>Final Project:  <font color=red> <b> PYREVIT</font>

# %% [markdown]
# ### <font color = blue> <b>What is PyRevit? </font>

# %% [markdown]
# #### Before we dive in PyRevit, I would like to introduce to you a little about Revit API. <font color=purple>API</font> stands for <font color=purple>Application Programming Interface,</font> Revit is a complex 3D building information modeling software and it's written in C Sharp (C#) language. Together API is an interface between third party developers and the software itself. Keep in mind the third developers can't create all the tools of functionality that you see in the software but only the stuffs that the developers of this application have decided to expose to the outside world to use and modified.

# %% [markdown]
# #### Third party developer like us create <font color = blue >PyRevit</font> inside Revit enviroment. It is basically Python engine for us actually write our python scripts on Revit tools and create buttons for those as nice user interface so it’s really easy to use and easy to find and much more understandable. If you hold down ALT and click on one of these tools that you created in PyRevit, it takes you to the python script that is behind the tool

# %% [markdown]
# #### this is the link to download the PyRevit [Gibhub](https://github.com/eirannejad/pyRevit)

# %% [markdown]
# #### PyRevit has appeared in Revit after you download
# ![InkedCapture_LI.jpg](attachment:59740da0-a13b-4edf-81ef-fbc56efc48eb.jpg)

# %% [markdown]
# #### As you can see from the above image, there is a tab called <font color=purple>Add-Ins</font>. An <font color=purple>Interactive Python Shell</font>, it is also called <font color=purple>RPS (Revitpythonshell)</font> is downloaded in there. <font color=purple>RPS</font> is an add-on for Revit, It is used as a sketch pad for ideas, we basically want to test and inspect the ideas before we actually implement them in our script.

# %% [markdown]
# ![Capture2.PNG](attachment:ef74725e-c0dc-4ee6-8caf-661c377bc788.PNG)

# %% [markdown]
# ![Screenshot (7).png](attachment:13cbe9d0-62cf-4438-afb3-22a1d4cb6321.png)

# %% [markdown]
# ![Screenshot (8).png](attachment:53387239-464d-45a9-b4c7-a2b11b012524.png)

# %% [markdown]
# #### We are going to use it a lot so you need to down load it and this is the link: <font color=pink>[Github](https://github.com/architecture-building-systems/revitpythonshell)</font>
